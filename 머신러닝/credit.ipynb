# %%
import pandas as pd

# %%
train = pd.read_csv("train.csv")
train.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0      0      F   N       N          0      202500.0  Commercial associate
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
#
#                         edu_type     family_type           house_type  \
# 0               Higher education         Married  Municipal apartment
# 1  Secondary / secondary special  Civil marriage    House / apartment
# 2               Higher education         Married    House / apartment
# 3  Secondary / secondary special         Married    House / apartment
# 4               Higher education         Married    House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# ...

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0  26457      M   Y       N          0      112500.0             Pensioner
# 1  26458      F   N       Y          0      135000.0         State servant
# 2  26459      F   N       Y          0       69372.0               Working
# 3  26460      M   Y       N          0      112500.0  Commercial associate
# 4  26461      F   Y       Y          0      225000.0         State servant
#
#                         edu_type     family_type         house_type  \
# 0  Secondary / secondary special  Civil marriage  House / apartment
# 1               Higher education         Married  House / apartment
# 2  Secondary / secondary special         Married  House / apartment
# 3  Secondary / secondary special         Married  House / apartment
# 4               Higher education         Married  House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# ...

# %%
train.shape
# Out:
# (26457, 20)

# %%
test.shape
# Out:
# (10000, 19)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_columns = None
import matplotlib
from matplotlib import font_manager, rc
import platform

# %%
try:
    if platform.system() == 'Windows':
        font_name = font_manager.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
        rc('font',family=font_name)
    else:
        rc('font', family='AppleGothic')
except:
    pass
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
train.groupby('gender').count()['index']
# Out:
# gender
# F    17697
# M     8760
# Name: index, dtype: int64

# %%
train.groupby('gender').count()['index']
# Out:
# gender
# F    17697
# M     8760
# Name: index, dtype: int64

# %%
#데이터 시각화

# %%
#성별 gender
gender_counts = train['gender'].value_counts()
plt.figure(figsize=(5,5))
plt.bar(gender_counts.index, gender_counts.values, color=['lightcoral', 'pink'])
plt.title('Gender Distribution')
plt.xlabel('성별')
plt.ylabel('Count')
plt.show()

gender_counts = train['gender'].value_counts()
total = gender_counts.sum()
gender_ratios = gender_counts / total * 100
plt.figure(figsize=(6,6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightcoral','pink'], wedgeprops=dict(width=0.3))
plt.show()

# %%
# 차 소유 여부 car
car_counts = train['car'].value_counts()
plt.figure(figsize=(5,5))
plt.bar(car_counts.index, car_counts.values, color=["lightcoral","pink"])
plt.title("Car Distribution")
plt.xlabel("차 소유 여부")
plt.ylabel("Count")
plt.show()

car_counts = train['car'].value_counts()
total = car_counts.sum()
car_ratios = car_counts / total * 100
plt.figure(figsize=(6,6))
plt.pie(car_counts, labels=car_counts.index, autopct='%1.1f%%', startangle=90, colors=["lightcoral", "pink"], wedgeprops=dict(width=0.3))
plt.show()

# %%
#부동산 소유 여부 Reality
reality_counts = train['reality'].value_counts()
plt.figure(figsize=(5,5))
plt.bar(reality_counts.index, reality_counts.values, color=['lightcoral','pink'])
plt.title('Reality Distribution')
plt.xlabel('부동산 소유 여부')
plt.ylabel('Count')
plt.show()

reality_counts = train['reality'].value_counts()
total = reality_counts.sum()
reality_ratio = reality_counts / total * 100
plt.figure(figsize=(6,6))
plt.pie(reality_counts, labels=reality_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightcoral','pink'], wedgeprops=dict(width=0.3))
plt.show()

# %%
train.groupby('child_num').count()['index']
# Out:
# child_num
# 0     18340
# 1      5386
# 2      2362
# 3       306
# 4        47
# 5        10
# 7         2
# 14        3
# 19        1
# Name: index, dtype: int64

# %%
import seaborn as sns
#자식 수 child_num
child_num_counts = train['child_num'].value_counts()
plt.figure(figsize=(8,5))
bars = plt.bar(child_num_counts.index, child_num_counts.values, color=['lightcoral'])
plt.title('Distribution by Number of Children')
plt.xlabel('자식 수')
plt.ylabel('Count')
plt.xticks(child_num_counts.index)
plt.show()

plt.figure(figsize=(8,6))
sns.boxplot(data=train, y="child_num", width=0.5, color="lightblue")
plt.title("Distribution by Number of Children")
plt.xlabel('자식 수')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8,6))
plt.boxplot(train['child_num'], vert=False, widths=0.6, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.xlabel('자식 수')
plt.ylabel('Count')
plt.title('Distribution of Child Count')
plt.show()

# %%
#연간 소득 incom_total
plt.figure(figsize=(8,6))
sns.boxplot(data=train, y="income_total", width=0.3, color="lightblue")
plt.title("Annual Income Distribution")
plt.ylim(20000,900000)
plt.show()

# %%
train.income_total.max()
# Out:
# 1575000.0

# %%
#소득 분류 income_type
income_type_counts = train['income_type'].value_counts()
plt.figure(figsize=(7,5))
plt.bar(income_type_counts.index, income_type_counts.values, color=['#FF6347', '#FF7F50', '#FF8C00', '#FFA07A', '#FFD700'])
plt.title('Distribution of Income Type')
plt.xlabel('직업')
plt.ylabel('Count')
plt.show()

income_type_counts = train['income_type'].value_counts()
total = income_type_counts.sum()
income_type_ratios = income_type_counts / total * 100
plt.figure(figsize=(6,6))
plt.pie(income_type_counts, labels=income_type_counts.index, autopct='%1.1f%%', startangle=90, colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd'], wedgeprops=dict(width=0.3))
plt.show()

# %%
#교육 수준 edu_type
edu_type_counts = train['edu_type'].value_counts()

plt.figure(figsize=(8,5))
bars = plt.bar(edu_type_counts.index, edu_type_counts.values, color=['lightcoral'])
plt.title('Distribution by Education Type')
plt.xlabel('Education Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# 결혼 여부 family_type
family_type_counts = train['family_type'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(family_type_counts, labels=family_type_counts.index, autopct='%1.1f%%', startangle=90, 
        colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd'], wedgeprops=dict(width=0.3))
plt.title('Distribution by Family Type')
plt.show()

# %%
# 거주지 타입 house_type
house_type_counts = train['house_type'].value_counts()
total = house_type_counts.sum()
house_type_ratios = house_type_counts / total * 100

plt.figure(figsize=(10, 6))
ax = sns.barplot(y=house_type_counts.index, x=house_type_counts.values, hue=house_type_ratios, palette='Set2', legend=False)
plt.title('Distribution by House Type')
plt.xlabel('Count')
plt.ylabel('House Type')

for i, v in enumerate(house_type_ratios):
    ax.text(v + 3, i, f'{v:.1f}%', color='black', va='center')

plt.show()

# %%
# 핸드폰 소지 여부 FLAG_MOBIL
FLAG_MOBIL_counts = train['FLAG_MOBIL'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(FLAG_MOBIL_counts, labels=FLAG_MOBIL_counts.index, autopct='%1.1f%%', startangle=90, 
        colors=['#1f77b4', '#ff7f0e'], wedgeprops=dict(width=0.3))
plt.title('Distribution by FLAG_MOBILE')
plt.show()

# %%
#업무용 전화 소유 여부 work_phone
work_phone_counts = train['work_phone'].value_counts()

plt.figure(figsize=(5,5))
plt.bar(['Y', 'N'], work_phone_counts.values, color=['lightcoral', 'pink'])
plt.title('Work Phone Distribution')
plt.xlabel('Work Phone 여부')
plt.ylabel('Count')
plt.show()

work_phone_counts = train['work_phone'].value_counts()
total = work_phone_counts.sum()
work_phone_ratio = work_phone_counts / total * 100
plt.figure(figsize=(6,6))
plt.pie(work_phone_counts, labels=work_phone_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'pink'], wedgeprops=dict(width=0.3))
plt.title('Work Phone Distribution')
plt.show()

# %%
#이메일 소유 여부 eamil
email_counts = train['email'].value_counts()
plt.figure(figsize=(5,5))
plt.bar(['Y', 'N'], email_counts.values, color=['lightcoral', 'pink'])
plt.title('Email Distribution')
plt.xlabel('email 소유 여부')
plt.ylabel('Count')
plt.show()

email_counts = train['email'].value_counts()
total = email_counts.sum()
eamil_ratios = email_counts / total * 100
plt.figure(figsize=(6,6))
plt.pie(email_counts, labels=email_counts.index, autopct='%1.1f%%', startangle=90,
        colors=['lightcoral','pink'], wedgeprops=dict(width=0.3))
plt.show()

# %%
#직업 종류 occyp_type
sns.set_palette("pastel")

plt.figure(figsize=(10,6))
sns.countplot(data=train, y="occyp_type", palette='RdPu', order=train['occyp_type'].value_counts().index, legend=False)
plt.title('직업 종류', color='black')
plt.show()
# Out:
# C:\Users\kosa\AppData\Local\Temp\ipykernel_14340\1388600138.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=train, y="occyp_type", palette='RdPu', order=train['occyp_type'].value_counts().index, legend=False)

# %%
# 가족 구성원 수 family_size
family_size_counts = train['family_size'].value_counts()
plt.figure(figsize=(8,5))
bars = plt.bar(family_size_counts.index, family_size_counts.values, color=['lightgreen'])
plt.title('Distribution by Number of Family Size')
plt.xlabel('가족 수')
plt.ylabel('Count')
plt.xticks(family_size_counts.index)
plt.show()

plt.figure(figsize=(8,6))
sns.boxplot(data=train, y="family_size", width=0.5, color="lightgreen")
plt.title("Distribution by Family Size")
plt.xlabel('자식 수')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(8,6))
plt.boxplot(train['family_size'], vert=False, widths=0.6, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.xlabel('가족 수')
plt.ylabel('Count')
plt.title('Distribution by Family Size')
plt.show()

# %%
#신용카드 등급 credit
sns.countplot(data=train, x="credit", palette="Reds", saturation=1000, hue="credit", legend=False)
plt.title('Credit Distribution', color="black")
plt.show()

credit_counts = train['credit'].value_counts()
total = credit_counts.sum()
credit_ratio = credit_counts / total * 100
plt.figure(figsize=(6,6))
plt.pie(credit_counts, labels=credit_counts.index, autopct = '%1.1f%%', startangle=90, colors=['lightsalmon', 'peachpuff', 'lightcoral'],
         wedgeprops=dict(width=0.3))
plt.title('Credit Distribution')
plt.show()

# %%
#age 나이대
import numpy as np
train1 = train.copy()
train1['age'] = (abs(train1['DAYS_BIRTH']) / 365.5).round().astype(np.int32)
train1['age'].plot.hist(bins=range(10,81,10),color='orange')
plt.xlabel('age')
plt.title('Age Distribution')
plt.show()

age_group = (train1['age'] // 10) * 10
age_counts = age_group.value_counts()
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', colors=['#8fd9b6', '#ffd966', '#ff6f61', '#8e7cc3', '#aec7e8'])
plt.title('Age Distribution')
plt.show()

# %%
#재직 기간 DAYS_EMPLOYED
train1['worked_year'] = train1['DAYS_EMPLOYED'].apply(lambda x: 0 if x >= 0 else round(abs(x) / 365.5, 2))
sns.displot(data=train1, x="worked_year", kind='hist', color='orange')
plt.title('Average Worked year Distribution')
plt.show()

# %%
#begin_month 발급된 카드 사용 기간
train1['BEGIN_MONTH'] = train1['begin_month'].apply(lambda x: 0 if x >= 0 else round(abs(x) / 12, 2))
sns.displot(data=train1,x='BEGIN_MONTH',kind='kde',color='orange')
plt.show()

# %%
#phone 전화 소유 여부
phone_counts = train['phone'].value_counts()
plt.figure(figsize=(5,5))
plt.bar(phone_counts.index, phone_counts.values, color=['lightcoral','pink'])
plt.title('Phone Distribution')
plt.xlabel('Phone')
plt.ylabel('Count')
plt.xticks([0, 1], ['N', 'Y'])
plt.show()


phone_counts = train['phone'].value_counts()
total = phone_counts.sum()
phone_ratio = phone_counts / total * 100
plt.figure(figsize=(6,6))
plt.pie(phone_counts, labels=phone_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightcoral','pink'], wedgeprops=dict(width=0.3))
plt.title('Phone Distribution')
plt.show()

# %%
train.hist(figsize=(10, 9))
plt.tight_layout()
plt.show()

# %%
#데이터 전처리

# %%
#결측치 처리
train.loc[train['DAYS_EMPLOYED'] > 0, 'occyp_type'] = 'unemployed'
test.loc[test['DAYS_EMPLOYED'] > 0, 'occyp_type'] = 'unemployed'

# %%
train.loc[(train['income_type'] == 'Student'), 'occyp_type'] = 'unemployed'
test.loc[(test['income_type'] == 'Student'), 'occyp_type'] = 'unemployed'

# %%
train = train.fillna('Unknown')
test = test.fillna('Unknown')

# %%
print(train.isnull().sum())
print(test.isnull().sum())
# Out:
# index            0
# gender           0
# car              0
# reality          0
# child_num        0
# income_total     0
# income_type      0
# edu_type         0
# family_type      0
# house_type       0
# DAYS_BIRTH       0
# DAYS_EMPLOYED    0
# FLAG_MOBIL       0
# work_phone       0
# phone            0
# email            0
# occyp_type       0
# family_size      0
# begin_month      0
# credit           0
# dtype: int64
# index            0
# gender           0
# car              0
# reality          0
# child_num        0
# income_total     0
# income_type      0
# edu_type         0
# family_type      0
# house_type       0
# DAYS_BIRTH       0
# DAYS_EMPLOYED    0
# FLAG_MOBIL       0
# work_phone       0
# phone            0
# email            0
# occyp_type       0
# family_size      0
# begin_month      0
# dtype: int64

# %%
#이상치
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.boxplot(x=train['child_num'])
plt.show()

# %%
sns.set(style="whitegrid")

grouped = train.groupby(['child_num', 'credit'])['credit'].count().unstack()
grouped = grouped.div(grouped.sum(axis=1), axis=0)

plt.figure(figsize=(10, 6))
grouped.plot(kind='bar', stacked=True, colormap='PuRd')
plt.title('Credit Distribution Ratio by Child Number', fontsize=20)
plt.xlabel('Number of Children', fontsize=12)
plt.ylabel('Ratio', fontsize=12)
plt.legend(title='Credit', labels=['0', '1', '2'])
plt.show()

# %%
train = train[(train['child_num'] <= 7)].reset_index(drop=True)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.boxplot(x=train['family_size'])
plt.show()

# %%
sns.set(style="whitegrid")

grouped = train.groupby(['family_size', 'credit'])['credit'].count().unstack()
grouped = grouped.div(grouped.sum(axis=1), axis=0)

plt.figure(figsize=(10, 6))
grouped.plot(kind='bar', stacked=True, colormap='PuRd')
plt.title('Credit Distribution Ratio by Family Size', fontsize=20)
plt.xlabel('Number Family Size', fontsize=12)
plt.ylabel('Ratio', fontsize=12)
plt.legend(title='Credit', labels=['0', '1', '2'])
plt.show()

# %%
train = train[(train['family_size'] <= 7)].reset_index(drop=True)

# %%
sns.set(style="whitegrid")

grouped = train.groupby(['family_size', 'credit'])['credit'].count().unstack()
grouped = grouped.div(grouped.sum(axis=1), axis=0)

plt.figure(figsize=(10, 6))
grouped.plot(kind='bar', stacked=True, colormap='PuRd')
plt.title('Credit Distribution Ratio by Family Size', fontsize=20)
plt.xlabel('Number Family Size', fontsize=12)
plt.ylabel('Ratio', fontsize=12)
plt.legend(title='Credit', labels=['0', '1', '2'])
plt.show()

# %%
train["family_size"].value_counts()
# Out:
# 2.0    14106
# 1.0     5109
# 3.0     4632
# 4.0     2260
# 5.0      291
# 6.0       44
# 7.0        9
# Name: family_size, dtype: int64

# %%
train.drop(["FLAG_MOBIL"], axis=1, inplace=True)
test.drop(["FLAG_MOBIL"], axis=1, inplace=True)

# %%
train.drop(["index"], axis=1, inplace=True)
test.drop(["index"], axis=1, inplace=True)

# %%
test.head()
# Out:
#   gender car reality  child_num  income_total           income_type  \
# 0      M   Y       N          0      112500.0             Pensioner
# 1      F   N       Y          0      135000.0         State servant
# 2      F   N       Y          0       69372.0               Working
# 3      M   Y       N          0      112500.0  Commercial associate
# 4      F   Y       Y          0      225000.0         State servant
#
#                         edu_type     family_type         house_type  \
# 0  Secondary / secondary special  Civil marriage  House / apartment
# 1               Higher education         Married  House / apartment
# 2  Secondary / secondary special         Married  House / apartment
# 3  Secondary / secondary special         Married  House / apartment
# 4               Higher education         Married  House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  work_phone  phone  email  occyp_type  \
# 0      -21990         365243           0      1      0  unemployed
# ...

# %%
train.loc[train['DAYS_EMPLOYED']>0, 'DAYS_EMPLOYED'] = 0
test.loc[test['DAYS_EMPLOYED']>0, 'DAYS_EMPLOYED'] = 0

# %%
test.head()
# Out:
#   gender car reality  child_num  income_total           income_type  \
# 0      M   Y       N          0      112500.0             Pensioner
# 1      F   N       Y          0      135000.0         State servant
# 2      F   N       Y          0       69372.0               Working
# 3      M   Y       N          0      112500.0  Commercial associate
# 4      F   Y       Y          0      225000.0         State servant
#
#                         edu_type     family_type         house_type  \
# 0  Secondary / secondary special  Civil marriage  House / apartment
# 1               Higher education         Married  House / apartment
# 2  Secondary / secondary special         Married  House / apartment
# 3  Secondary / secondary special         Married  House / apartment
# 4               Higher education         Married  House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  work_phone  phone  email  occyp_type  \
# 0      -21990              0           0      1      0  unemployed
# ...

# %%
train['DAYS_BIRTH'] = train['DAYS_BIRTH'] * -1
test['DAYS_BIRTH'] = test['DAYS_BIRTH'] * -1

train['begin_month'] = train['begin_month'] * -1
test['begin_month'] = test['begin_month'] * -1

train['DAYS_EMPLOYED'] = train['DAYS_EMPLOYED'] * -1
test['DAYS_EMPLOYED'] = test['DAYS_EMPLOYED'] * -1

# %%
train.head()
# Out:
#   gender car reality  child_num  income_total           income_type  \
# 0      F   N       N          0      202500.0  Commercial associate
# 1      F   N       Y          1      247500.0  Commercial associate
# 2      M   Y       Y          0      450000.0               Working
# 3      F   N       Y          0      202500.0  Commercial associate
# 4      F   Y       Y          0      157500.0         State servant
#
#                         edu_type     family_type           house_type  \
# 0               Higher education         Married  Municipal apartment
# 1  Secondary / secondary special  Civil marriage    House / apartment
# 2               Higher education         Married    House / apartment
# 3  Secondary / secondary special         Married    House / apartment
# 4               Higher education         Married    House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  work_phone  phone  email   occyp_type  \
# ...

# %%
test.head()
# Out:
#   gender car reality  child_num  income_total           income_type  \
# 0      M   Y       N          0      112500.0             Pensioner
# 1      F   N       Y          0      135000.0         State servant
# 2      F   N       Y          0       69372.0               Working
# 3      M   Y       N          0      112500.0  Commercial associate
# 4      F   Y       Y          0      225000.0         State servant
#
#                         edu_type     family_type         house_type  \
# 0  Secondary / secondary special  Civil marriage  House / apartment
# 1               Higher education         Married  House / apartment
# 2  Secondary / secondary special         Married  House / apartment
# 3  Secondary / secondary special         Married  House / apartment
# 4               Higher education         Married  House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  work_phone  phone  email  occyp_type  \
# 0       21990              0           0      1      0  unemployed
# ...

# %%
#Feature 생성

# %%
# ability : 소득/(살아온 일수 + 근무 일수)
train['ability'] = train['income_total'] / (train['DAYS_BIRTH'] + train['DAYS_EMPLOYED'])
test['ability'] = test['income_total'] / (test['DAYS_BIRTH'] + test['DAYS_EMPLOYED'])

# %%
# income_mean : 소득 / 가족수
train['income_mean'] = train['income_total'] / train['family_size']
test['income_mean'] = test['income_total'] / test['family_size']

# %%
# dependency_ratio   부양 비율 : 자녀수 / 가족수
train['dependency_ratio'] = train['child_num'] / train['family_size']
test['dependency_ratio'] = test['child_num'] / test['family_size']

# %%
# employed_life_ratio  생에 근무 기간 : 근무 일수 / 살아온 일수
train['employed_life_ratio'] = train['DAYS_EMPLOYED'] / train['DAYS_BIRTH']
test['employed_life_ratio'] = test['DAYS_EMPLOYED'] / test['DAYS_BIRTH']

# %%
# employed_begin_ratio   신용카드 발급 후 근무 경과 일수 : 근무 일수 / 카드 개설 후 경과 개월 수
train['employed_begin_ratio'] = train['DAYS_EMPLOYED'] / train['begin_month']
test['employed_begin_ratio'] = test['DAYS_EMPLOYED'] / test['begin_month']

# %%
# income_per_day  하루 평균 소득 : 총 소득 / 살아온 일 수
train['income_per_day'] = train['income_total'] / train['DAYS_BIRTH']
test['income_per_day'] = test['income_total'] / test['DAYS_BIRTH']

# %%
# age 나이 : 살아온 일수 / 365
train['age'] = train['DAYS_BIRTH'] / 365
test['age'] = test['DAYS_BIRTH'] / 365

# %%
# age_group 나이 그룹 : 나이 구간별 분포
train['age_group'] = pd.cut(train['age'], bins=[0, 25, 35, 45, 55, 65, 100], labels=['<25', '25-35', '35-45', '45-55', '55-65', '65+'])
test['age_group'] = pd.cut(test['age'], bins=[0, 25, 35, 45, 55, 65, 100], labels=['<25', '25-35', '35-45', '45-55', '55-65', '65+'])

# %%
train.head()
# Out:
#   gender car reality  child_num  income_total           income_type  \
# 0      F   N       N          0      202500.0  Commercial associate
# 1      F   N       Y          1      247500.0  Commercial associate
# 2      M   Y       Y          0      450000.0               Working
# 3      F   N       Y          0      202500.0  Commercial associate
# 4      F   Y       Y          0      157500.0         State servant
#
#                         edu_type     family_type           house_type  \
# 0               Higher education         Married  Municipal apartment
# 1  Secondary / secondary special  Civil marriage    House / apartment
# 2               Higher education         Married    House / apartment
# 3  Secondary / secondary special         Married    House / apartment
# 4               Higher education         Married    House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  work_phone  phone  email   occyp_type  \
# ...

# %%
# 스케일링 및 인코딩

# %%
#데이터 확인
numerical_feats = train.dtypes[train.dtypes != "object"].index.tolist()
numerical_feats.remove('credit')
print("Number of Numerical features: ", len(numerical_feats))

categorical_feats = train.dtypes[train.dtypes == "object"].index.tolist()
print("Number of Categorical features: ", len(categorical_feats))
# Out:
# Number of Numerical features:  17
# Number of Categorical features:  8

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np

# %%
# log 변환
log_features = ['income_total']
for feature in log_features:
    train[feature] = np.log1p(train[feature])
    test[feature] = np.log1p(test[feature])

# %%
category_features = train.select_dtypes(include=['object', 'category']).columns
label_encoders={}

# %%
for feature in category_features:
    le = LabelEncoder()
    train[feature] = le.fit_transform(train[feature].astype(str))
    prev_classes = list(le.classes_)

    for label in np.unique(test[feature].astype(str)):
        if label not in prev_classes:
            prev_classes.append(label)

    le.classes_ = np.array(prev_classes)
    test[feature] = le.transform(test[feature].astype(str))
    label_encoders[feature] = le

# %%
train.replace([np.inf, -np.inf], np.nan, inplace=True)
test.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
train.fillna(train.mean(), inplace=True)
test.fillna(test.mean(), inplace=True)

# %%
numeric_features = list(train.select_dtypes(include=[np.number]).columns)

# %%
from sklearn.preprocessing import StandardScaler
numerical_feats.remove('income_total')
scaler = StandardScaler()
train[numerical_feats] = scaler.fit_transform(train[numerical_feats])
test[numerical_feats] = scaler.transform(test[numerical_feats])

# %%
print("Inf values in train data:")
print(train.applymap(np.isinf).sum())
print("Inf values in test data:")
print(test.applymap(np.isinf).sum())
# Out:
# Inf values in train data:
# gender                  0
# car                     0
# reality                 0
# child_num               0
# income_total            0
# income_type             0
# edu_type                0
# family_type             0
# house_type              0
# DAYS_BIRTH              0
# DAYS_EMPLOYED           0
# work_phone              0
# phone                   0
# email                   0
# occyp_type              0
# family_size             0
# begin_month             0
# credit                  0
# ability                 0
# income_mean             0
# dependency_ratio        0
# employed_life_ratio     0
# employed_begin_ratio    0
# income_per_day          0
# age                     0
# age_group               0
# dtype: int64
# Inf values in test data:
# gender                  0
# car                     0
# reality                 0
# child_num               0
# income_total            0
# income_type             0
# edu_type                0
# ...

# %%
train.head()
# Out:
#    gender  car  reality  child_num  income_total  income_type  edu_type  \
# 0       0    0        0  -0.589850     12.218500            0         1
# 1       0    0        1   0.795036     12.419170            0         4
# 2       1    1        1  -0.589850     13.017005            4         1
# 3       0    0        1  -0.589850     12.218500            0         4
# 4       0    1        1  -0.589850     11.967187            2         1
#
#    family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  work_phone     phone  \
# 0            1           2   -0.490076       1.059065   -0.538321 -0.645632
# 1            0           1   -1.089581      -0.277867   -0.538321 -0.645632
# 2            1           1    0.744635       0.943049   -0.538321  1.548870
# 3            1           1   -0.207101      -0.044990   -0.538321  1.548870
# 4            1           1   -0.219239      -0.039505   -0.538321 -0.645632
#
#       email  occyp_type  family_size  begin_month  credit   ability  \
# ...

# %%
test.head()
# Out:
#    gender  car  reality  child_num  income_total  income_type  edu_type  \
# 0       1    1        0   -0.58985     11.630717            1         4
# 1       0    0        1   -0.58985     11.813037            2         1
# 2       0    0        1   -0.58985     11.147253            4         4
# 3       1    1        0   -0.58985     11.630717            0         4
# 4       0    1        1   -0.58985     12.323860            2         1
#
#    family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  work_phone     phone  \
# 0            0           1    1.435531      -0.927559   -0.538321  1.548870
# 1            1           1    0.715362       2.730547   -0.538321  1.548870
# 2            1           1   -0.016944      -0.836011    1.857628  1.548870
# 3            1           1    0.788188       0.140215    1.857628 -0.645632
# 4            1           1    0.443573       3.031768    1.857628 -0.645632
#
#       email  occyp_type  family_size  begin_month   ability  income_mean  \
# ...

# %%
print(f'train : {train.columns} \n test : {test.columns}')
# Out:
# train : Index(['gender', 'car', 'reality', 'child_num', 'income_total', 'income_type',
#        'edu_type', 'family_type', 'house_type', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'work_phone', 'phone', 'email', 'occyp_type', 'family_size',
#        'begin_month', 'credit', 'ability', 'income_mean', 'dependency_ratio',
#        'employed_life_ratio', 'employed_begin_ratio', 'income_per_day', 'age',
#        'age_group'],
#       dtype='object')
#  test : Index(['gender', 'car', 'reality', 'child_num', 'income_total', 'income_type',
#        'edu_type', 'family_type', 'house_type', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'work_phone', 'phone', 'email', 'occyp_type', 'family_size',
#        'begin_month', 'ability', 'income_mean', 'dependency_ratio',
#        'employed_life_ratio', 'employed_begin_ratio', 'income_per_day', 'age',
#        'age_group'],
#       dtype='object')

# %%
if 'credit' in train.columns:
    target = train['credit']
    train = train.drop('credit', axis=1)
else:
    raise ValueError("The 'credit' column is not found in the train dataframe.")

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(train, target, test_size=0.3, random_state=42)

# %%
#모델

# %%
#랜덤 포레스트
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_valid)
y_pred_proba = rf.predict_proba(X_valid)
from sklearn.metrics import accuracy_score, log_loss
print("Accuracy:", accuracy_score(y_valid, y_pred))
print("Log Loss:", log_loss(y_valid, y_pred_proba))
#Accuracy: 0.7095514112903226
#Log Loss: 0.8997427485837229
# Out:
# Accuracy: 0.7095514112903226
# Log Loss: 0.8997427485837229

# %%
#로지스틱 회귀
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=42, max_iter=1000)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_valid)
y_pred_proba = lr.predict_proba(X_valid)
print("Accuracy:", accuracy_score(y_valid, y_pred))
print("Log Loss:", log_loss(y_valid, y_pred_proba))
#Accuracy: 0.6684727822580645
#Log Loss: 0.8349004142791947
# Out:
# Accuracy: 0.6684727822580645
# Log Loss: 0.8349004142791947

# %%
#SVM
from sklearn.svm import SVC
svm = SVC(random_state=42, probability=True)
svm.fit(X_train, y_train)
y_pred = svm.predict(X_valid)
y_pred_proba = svm.predict_proba(X_valid)
print("Accuracy:", accuracy_score(y_valid, y_pred))
print("Log Loss:", log_loss(y_valid, y_pred_proba))
#Accuracy: 0.6610383064516129
#Log Loss: 0.8363108499002782
# Out:
# Accuracy: 0.6610383064516129
# Log Loss: 0.8363108499002782

# %%
#GBM
from sklearn.ensemble import GradientBoostingClassifier
gbm = GradientBoostingClassifier(random_state=42)
gbm.fit(X_train, y_train)
y_pred = gbm.predict(X_valid)
y_pred_proba = gbm.predict_proba(X_valid)
print("GBM Accuracy:", accuracy_score(y_valid, y_pred))
print("GBM Log Loss:", log_loss(y_valid, y_pred_proba))
#GBM Accuracy: 0.6987147177419355
#GBM Log Loss: 0.7769052945340501
# Out:
# GBM Accuracy: 0.6987147177419355
# GBM Log Loss: 0.7769052945340501

# %%
#Light GBM
import lightgbm
lgb = lightgbm.LGBMClassifier(random_state=42)
lgb.fit(X_train, y_train)
y_pred = lgb.predict(X_valid)
y_pred_proba = lgb.predict_proba(X_valid)
print("LightGBM Accuracy:", accuracy_score(y_valid, y_pred))
print("LightGBM Log Loss:", log_loss(y_valid, y_pred_proba))
#LightGBM Accuracy: 0.7113155241935484
#LightGBM Log Loss: 0.7368883829118323
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000651 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2328
# [LightGBM] [Info] Number of data points in the train set: 18515, number of used features: 25
# [LightGBM] [Info] Start training from score -2.081767
# [LightGBM] [Info] Start training from score -1.445880
# [LightGBM] [Info] Start training from score -0.446675
# LightGBM Accuracy: 0.7113155241935484
# LightGBM Log Loss: 0.7368883829118323

# %%
#CatBoost 캣부스트
from catboost import CatBoostClassifier
cat = CatBoostClassifier(random_state=42, verbose=0)
cat.fit(X_train, y_train)
y_pred = cat.predict(X_valid)
y_pred_proba = cat.predict_proba(X_valid)
print("CatBoost Accuracy:", accuracy_score(y_valid, y_pred))
print("CatBoost Log Loss:", log_loss(y_valid, y_pred_proba))
#CatBoost Accuracy: 0.7155997983870968
#CatBoost Log Loss: 0.7300653320503562
# Out:
# CatBoost Accuracy: 0.7155997983870968
# CatBoost Log Loss: 0.7300653320503562

# %%
#Decision Tree 결정 트리
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_valid)
y_pred_proba = dt.predict_proba(X_valid)
print("Decision Tree Accuracy:", accuracy_score(y_valid, y_pred))
print("Decision Tree Log Loss:", log_loss(y_valid, y_pred_proba))
#Decision Tree Accuracy: 0.6261340725806451
#Decision Tree Log Loss: 13.004584777226635
# Out:
# Decision Tree Accuracy: 0.6261340725806451
# Decision Tree Log Loss: 13.004584777226635

# %%
#KNN K-최근접 이웃
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_valid)
y_pred_proba = knn.predict_proba(X_valid)
print("KNN Accuracy:", accuracy_score(y_valid, y_pred))
print("KNN Log Loss:", log_loss(y_valid, y_pred_proba))
#KNN Accuracy: 0.643523185483871
#KNN Log Loss: 3.9590293091546243
# Out:
# KNN Accuracy: 0.643523185483871
# KNN Log Loss: 3.9590293091546243

# %%
#Naive Bayes 나이브 베이즈
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred = nb.predict(X_valid)
y_pred_proba = nb.predict_proba(X_valid)
print("Naive Bayes Accuracy:", accuracy_score(y_valid, y_pred))
print("Naive Bayes Log Loss:", log_loss(y_valid, y_pred_proba))
#Naive Bayes Accuracy: 0.6585181451612904
#Naive Bayes Log Loss: 1.0903317635326149
# Out:
# Naive Bayes Accuracy: 0.6585181451612904
# Naive Bayes Log Loss: 1.0903317635326149

# %%
#Neural Networks
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(random_state=42)
mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_valid)
y_pred_proba = mlp.predict_proba(X_valid)
print("Neural Network Accuracy:", accuracy_score(y_valid, y_pred))
print("Neural Network Log Loss:", log_loss(y_valid, y_pred_proba))
#Neural Network Accuracy: 0.6941784274193549
#Neural Network Log Loss: 0.8174279780600484
# Out:
# Neural Network Accuracy: 0.6941784274193549
# Neural Network Log Loss: 0.8174279780600484
# C:\Users\kosa\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
#AdaBoost 아다부스트
from sklearn.ensemble import AdaBoostClassifier
ad = AdaBoostClassifier(random_state=42)
ad.fit(X_train, y_train)
y_pred = ad.predict(X_valid)
y_pred_proba = ad.predict_proba(X_valid)
print("AdaBoost Accuracy:", accuracy_score(y_valid, y_pred))
print("AdaBoost Log Loss:", log_loss(y_valid, y_pred_proba))
#AdaBoost Accuracy: 0.6970766129032258
#AdaBoost Log Loss: 1.0810885994433848
# Out:
# AdaBoost Accuracy: 0.6970766129032258
# AdaBoost Log Loss: 1.0810885994433848

# %%
import optuna
from optuna import Trial
from optuna.samplers import TPESampler
from catboost import CatBoostClassifier
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold, train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
# Catboost 하이퍼파라미터 튜닝
def objective(trial: Trial) -> float:

    params_catboost = {
        'iterations': trial.suggest_int('iterations', 50, 500),
        'depth': trial.suggest_int('depth', 1, 9),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 1.0, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 10),
        'border_count': trial.suggest_int('border_count', 1, 255),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-8, 1.0, log=True),
        'eval_metric': 'MultiClass',
        'verbose': False,
    }
    
    X_train, X_valid, y_train, y_valid = train_test_split(train, target, test_size=0.3, random_state=42)
    
    model = CatBoostClassifier(**params_catboost)
    model.fit(X_train, y_train, eval_set=(X_valid, y_valid), early_stopping_rounds=100, verbose=False)
    
    pred = model.predict_proba(X_valid)
    log_score = log_loss(y_valid, pred)
    
    return log_score

# %%
sampler = TPESampler(seed=42)
study = optuna.create_study(
    study_name='catboost_parameter_opt',
    direction='minimize',
    sampler=sampler
)

study.optimize(objective, n_trials=300)
# Out:
# [I 2024-06-13 15:11:46,080] A new study created in memory with name: catboost_parameter_opt
# [I 2024-06-13 15:11:47,519] Trial 0 finished with value: 0.7480504405261316 and parameters: {'iterations': 218, 'depth': 9, 'learning_rate': 0.29106359131330695, 'min_child_samples': 6, 'border_count': 40, 'l2_leaf_reg': 1.7699302940633311e-07}. Best is trial 0 with value: 0.7480504405261316.
# [I 2024-06-13 15:11:48,071] Trial 1 finished with value: 0.7871536624903357 and parameters: {'iterations': 76, 'depth': 8, 'learning_rate': 0.15930522616241014, 'min_child_samples': 8, 'border_count': 6, 'l2_leaf_reg': 0.574485163632042}. Best is trial 0 with value: 0.7480504405261316.
# [I 2024-06-13 15:11:49,005] Trial 2 finished with value: 0.7934978441279641 and parameters: {'iterations': 425, 'depth': 2, 'learning_rate': 0.02310201887845294, 'min_child_samples': 2, 'border_count': 78, 'l2_leaf_reg': 0.00015777981883364995}. Best is trial 0 with value: 0.7480504405261316.
# ...

# %%
print("Best Score:", study.best_value)
print("Best trial:", study.best_trial.params)
# Out:
# Best Score: 0.7185284475779339
# Best trial: {'iterations': 499, 'depth': 9, 'learning_rate': 0.05370420437756091, 'min_child_samples': 10, 'border_count': 222, 'l2_leaf_reg': 0.34343360419918095}

# %%
best_params = study.best_trial.params

# %%
cat = CatBoostClassifier(random_state=42, **best_params)

cv = StratifiedKFold(n_splits=15, shuffle=True) 

cr_list = []
sub=np.zeros((test.shape[0], 3)) 

for train_index, test_index in cv.split(train, target) :
        x_train, x_test = train.iloc[list(train_index)], train.iloc[list(test_index)]
        y_train, y_test = target.iloc[list(train_index)], target.iloc[list(test_index)]
        model = cat.fit(x_train,y_train)
        pred = model.predict_proba(x_test)
        cross_entropy = log_loss(y_test, pred)
        cr_list.append(cross_entropy)
        sub +=model.predict_proba(test)
        
mysubmission = sub/15

score = sum(cr_list)/15
# Out:
# 0:	learn: 1.0673910	total: 32.4ms	remaining: 16.1s
# 1:	learn: 1.0395064	total: 66.1ms	remaining: 16.4s
# 2:	learn: 1.0153448	total: 98ms	remaining: 16.2s
# 3:	learn: 0.9939406	total: 128ms	remaining: 15.8s
# 4:	learn: 0.9744674	total: 158ms	remaining: 15.6s
# 5:	learn: 0.9575222	total: 188ms	remaining: 15.4s
# 6:	learn: 0.9419420	total: 218ms	remaining: 15.3s
# 7:	learn: 0.9282294	total: 249ms	remaining: 15.3s
# 8:	learn: 0.9159503	total: 280ms	remaining: 15.3s
# 9:	learn: 0.9040762	total: 310ms	remaining: 15.2s
# 10:	learn: 0.8940566	total: 340ms	remaining: 15.1s
# 11:	learn: 0.8845607	total: 369ms	remaining: 15s
# 12:	learn: 0.8761993	total: 399ms	remaining: 14.9s
# 13:	learn: 0.8683796	total: 429ms	remaining: 14.9s
# 14:	learn: 0.8615724	total: 460ms	remaining: 14.8s
# 15:	learn: 0.8552068	total: 492ms	remaining: 14.8s
# 16:	learn: 0.8494304	total: 522ms	remaining: 14.8s
# 17:	learn: 0.8440115	total: 553ms	remaining: 14.8s
# 18:	learn: 0.8389704	total: 583ms	remaining: 14.7s
# ...

# %%
print('logloss:', score)
# Out:
# logloss: 0.723105168153997

# %%
def plot_feature_importance(importance,names,model_type):
    
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    plt.figure(figsize=(10,8))

    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])

    plt.title(model_type + ' Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')

plot_feature_importance(model.get_feature_importance(),test.columns,'CATBOOST')

# %%
sample = pd.read_csv('sample_submission.csv')
sample.loc[:,1:] = mysubmission

sample.to_csv(f'submission_CatBoost{score:.4f}.csv', index=False)
# Out:
# C:\Users\kosa\AppData\Local\Temp\ipykernel_14340\3973253258.py:2: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   sample.loc[:,1:] = mysubmission

# %%
#Light GBM 튜닝
X_train, X_valid, y_train, y_valid = train_test_split(train, target, test_size=0.3, random_state=42)

def objective(trial: Trial) -> float:
    params_lgb = {
        'objective': 'multiclass',
        'num_class': num_classes,
        'metric': 'multi_logloss',
        'boosting_type': 'gbdt',
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 1.0, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 2, 256),
        'max_depth': trial.suggest_int('max_depth', -1, 50),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 100),
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 1.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 1.0, log=True),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'verbose': -1,
    }

    model = LGBMClassifier(**params_lgb)
    
    model.fit(
        X_train, y_train,
        eval_set=[(X_valid, y_valid)],
        callbacks=[lgb_early_stopping(stopping_rounds=100), lgb_log_evaluation(10)]
    )
    pred = model.predict_proba(X_valid)
    log_score = log_loss(y_valid, pred)
    
    return log_score

# %%
sampler = TPESampler(seed=42)
study = optuna.create_study(
    study_name='lightgbm_parameter_opt',
    direction='minimize',
    sampler=sampler
)
# Out:
# [I 2024-06-13 16:48:22,773] A new study created in memory with name: lightgbm_parameter_opt

# %%
import optuna
from optuna.samplers import TPESampler
from optuna import Trial
from lightgbm import LGBMClassifier
from lightgbm import early_stopping as lgb_early_stopping, log_evaluation as lgb_log_evaluation

# %%
unique_labels = target.unique()
num_classes = unique_labels.size

# %%
study.optimize(objective, n_trials=300)
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	valid_0's multi_logloss: 0.811908
# [20]	valid_0's multi_logloss: 0.776506
# [30]	valid_0's multi_logloss: 0.756549
# [40]	valid_0's multi_logloss: 0.7422
# [50]	valid_0's multi_logloss: 0.73244
# [60]	valid_0's multi_logloss: 0.724596
# [70]	valid_0's multi_logloss: 0.720757
# [80]	valid_0's multi_logloss: 0.718303
# [90]	valid_0's multi_logloss: 0.716177
# [I 2024-06-13 16:49:05,111] Trial 1 finished with value: 0.7150291765182405 and parameters: {'learning_rate': 0.05611516415334506, 'num_leaves': 244, 'max_depth': 37, 'min_data_in_leaf': 60, 'lambda_l1': 1.77071686435378e-07, 'lambda_l2': 1.7699302940633311e-07, 'feature_fraction': 0.4348501673009197, 'bagging_fraction': 0.9197056874649611, 'bagging_freq': 5}. Best is trial 1 with value: 0.7150291765182405.
# [100]	valid_0's multi_logloss: 0.715299
# Did not meet early stopping. Best iteration is:
# [96]	valid_0's multi_logloss: 0.715029
# ...

# %%
print("Best Score:", study.best_value)
print("Best trial:", study.best_trial.params)
# Out:
# Best Score: 0.6959939404972921
# Best trial: {'learning_rate': 0.07920724839023184, 'num_leaves': 177, 'max_depth': 28, 'min_data_in_leaf': 1, 'lambda_l1': 0.000723102406514351, 'lambda_l2': 0.021178282749982836, 'feature_fraction': 0.4118059485110705, 'bagging_fraction': 0.9583709224018843, 'bagging_freq': 2}

# %%
best_params_ = study.best_trial.params
lgb = LGBMClassifier(**best_params_)

# %%
cv = StratifiedKFold(n_splits=15, shuffle=True, random_state=42)

# %%
cr_list = []
sub = np.zeros((test.shape[0], 3))

# %%
for train_index, test_index in cv.split(train, target):
    x_train, x_test = train.iloc[train_index], train.iloc[test_index]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]
    model = lgb.fit(x_train, y_train)
    pred = model.predict_proba(x_test)
    cross_entropy = log_loss(y_test, pred)
    cr_list.append(cross_entropy)
    sub += model.predict_proba(test)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] feature_fraction is set=0.4118059485110705, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4118059485110705
# [LightGBM] [Warning] lambda_l1 is set=0.000723102406514351, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.000723102406514351
# [LightGBM] [Warning] lambda_l2 is set=0.021178282749982836, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.021178282749982836
# [LightGBM] [Warning] bagging_fraction is set=0.9583709224018843, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9583709224018843
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# ...

# %%
mysubmission = sub / 15
score = sum(cr_list) / 15

# %%
print('logloss:', score)
# Out:
# logloss: 0.6955796151358666

# %%
def plot_feature_importance(importance, names, model_type):
    
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    plt.figure(figsize=(10,20))

    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])

    plt.title(model_type + ' Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')
    
plot_feature_importance(model.feature_importances_, test.columns, 'LGBMClassifier')

# %%
sample = pd.read_csv('sample_submission.csv')
sample.loc[:,1:] = mysubmission

sample
# Out:
# C:\Users\kosa\AppData\Local\Temp\ipykernel_14340\2599295129.py:2: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   sample.loc[:,1:] = mysubmission
#       index         0         1         2
# 0     26457  0.059001  0.100220  0.840779
# 1     26458  0.202508  0.275219  0.522273
# 2     26459  0.032374  0.065910  0.901716
# 3     26460  0.097201  0.096165  0.806634
# 4     26461  0.080497  0.101153  0.818350
# ...     ...       ...       ...       ...
# 9995  36452  0.071833  0.231465  0.696702
# 9996  36453  0.227449  0.266591  0.505960
# 9997  36454  0.029166  0.069396  0.901437
# 9998  36455  0.097396  0.307635  0.594969
# 9999  36456  0.087501  0.235495  0.677004
#
# [10000 rows x 4 columns]

# %%
sample.to_csv(f'submission_LGB{score:.4f}.csv', index=False)

# %%
#앙상블

# %%
#soft voting
from sklearn.ensemble import VotingClassifier
voting_model = VotingClassifier(
    estimators=[('catboost', cat), ('lightgbm', lgb)],
    voting='soft'
)

# %%
cv = StratifiedKFold(n_splits=15, shuffle=True, random_state=42)
cr_list = []
sub = np.zeros((test.shape[0], 3))

for train_index, test_index in cv.split(train, target):
    x_train, x_test = train.iloc[train_index], train.iloc[test_index]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]
    voting_model.fit(x_train, y_train)
    pred = voting_model.predict_proba(x_test)
    cross_entropy = log_loss(y_test, pred)
    cr_list.append(cross_entropy)
    sub += voting_model.predict_proba(test)
# Out:
# 0:	learn: 1.0678782	total: 36.6ms	remaining: 18.2s
# 1:	learn: 1.0399720	total: 69ms	remaining: 17.2s
# 2:	learn: 1.0156997	total: 101ms	remaining: 16.7s
# 3:	learn: 0.9942723	total: 131ms	remaining: 16.3s
# 4:	learn: 0.9749516	total: 161ms	remaining: 15.9s
# 5:	learn: 0.9580019	total: 190ms	remaining: 15.6s
# 6:	learn: 0.9425091	total: 219ms	remaining: 15.4s
# 7:	learn: 0.9282312	total: 251ms	remaining: 15.4s
# 8:	learn: 0.9159595	total: 285ms	remaining: 15.5s
# 9:	learn: 0.9040724	total: 317ms	remaining: 15.5s
# 10:	learn: 0.8940545	total: 347ms	remaining: 15.4s
# 11:	learn: 0.8848182	total: 376ms	remaining: 15.2s
# 12:	learn: 0.8761815	total: 405ms	remaining: 15.1s
# 13:	learn: 0.8682245	total: 435ms	remaining: 15.1s
# 14:	learn: 0.8615778	total: 465ms	remaining: 15s
# 15:	learn: 0.8556499	total: 484ms	remaining: 14.6s
# 16:	learn: 0.8499722	total: 513ms	remaining: 14.6s
# 17:	learn: 0.8445907	total: 544ms	remaining: 14.5s
# 18:	learn: 0.8397451	total: 574ms	remaining: 14.5s
# ...

# %%
mysubmission = sub / 15
score = sum(cr_list) / 15

# %%
sample = pd.read_csv('sample_submission.csv')
sample.iloc[:, 1:] = mysubmission
sample.to_csv('ensemble.csv', index=False)

print(f"Ensemble log loss: {score}")
# Out:
# Ensemble log loss: 0.7013363232920911

# %%
#가중 평균
clfs = []
cat_ = pd.read_csv('submission_CatBoost0.7231.csv');
clfs.append(cat)
lgb_= pd.read_csv('submission_LGB0.6956.csv');
clfs.append(lgb)

# %%
data_id = cat_.iloc[:,0]

# %%
log_loss = [0.7226, 0.6956 ]

# %%
weighted_average1 = []
for i in range(len(cat_)):
    weighted_average1.append(lgb_.iloc[i,1]*0.7 + cat_.iloc[i,1]*0.3)

# %%
weighted_average2 = []
for i in range(len(cat_)):
    weighted_average2.append(lgb_.iloc[i,2]*0.7 + cat_.iloc[i,2]*0.3)

# %%
weighted_average3 = []
for i in range(len(cat_)):
    weighted_average3.append(lgb_.iloc[i,3]*0.7 + cat_.iloc[i,3]*0.3)

# %%
ensemble_= pd.DataFrame({'index': cat_.iloc[:,0], '0':weighted_average1, '1':weighted_average2,'2':weighted_average3})

# %%
ensemble_.to_csv('ensemble_.csv',index= False)
