# %%
import requests
from requests_file import FileAdapter

# %%
import os

# %%
s = requests.Session()
s.mount('file://', FileAdapter())
res = s.get('file:///sample.html')
res
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.content, "html.parser")

# %%
el = soup.select_one("h1")
print(el)
# Out:
# <h1>Hello CSS</h1>

# %%
el.text, el.name, el.attrs
# Out:
# ('Hello CSS', 'h1', {})

# %%
url = "https://finance.naver.com/marketindex/"
market_index = requests.get(url)
market_index
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(market_index.content, "html.parser")
price = soup.select_one("div.head_info > span.value")
print(price.text)
# Out:
# 1,362.70

# %%
soup.select("h1, span")
# Out:
# [<span>환전 고시 환율</span>,
#  <span class="blind">미국 USD</span>,
#  <span class="value">1,362.70</span>,
#  <span class="txt_krw"><span class="blind">원</span></span>,
#  <span class="blind">원</span>,
#  <span class="change"> 0.80</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2024.05.28 10:16</span>,
#  <span class="source">하나은행 기준</span>,
#  <span class="count">고시회차<span class="num">103</span>회</span>,
#  <span class="num">103</span>,
#  <span class="blind">일본 JPY(100엔)</span>,
#  <span class="value">868.71</span>,
#  <span class="txt_krw"><span class="blind">원</span></span>,
#  <span class="blind">원</span>,
#  <span class="change"> 0.40</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2024.05.28 10:16</span>,
#  <span class="source">하나은행 기준</span>,
#  <span class="count">고시회차<span class="num">103</span>회</span>,
#  <span class="num">103</span>,
#  <span class="blind">유럽연합 EUR</span>,
#  <span class="value">1,480.91</span>,
#  <span class="txt_krw"><span class="blind">원</span></span>,
#  <span class="blind">원</span>,
#  <span class="change">0.22</span>,
#  <span class="blind">상승</span>,
#  <span class="time">2024.05.28 10:16</span>,
#  <span class="source">하나은행 기준</span>,
#  <span class="count">고시회차<span class="num">103</span>회</span>,
#  <span class="num">103</span>,
#  <span class="blind">중국 CNY</span>,
#  <span class="value">187.70</span>,
#  <span class="txt_krw"><span class="blind">원</span></span>,
#  <span class="blind">원</span>,
#  <span class="change"> 0.12</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2024.05.28 10:16</span>,
#  <span class="source">하나은행 기준</span>,
#  <span class="count">고시회차<span class="num">103</span>회</span>,
#  <span class="num">103</span>,
#  <span>국제 시장 환율</span>,
#  <span class="blind">달러/일본 엔</span>,
#  <span class="value">156.7300</span>,
#  <span class="txt_jpy"><span class="blind">엔</span></span>,
#  <span class="blind">엔</span>,
#  <span class="change"> 0.2300</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2024.05.27</span>,
#  <span class="source">모닝스타 기준</span>,
#  <span class="blind">유로/달러</span>,
#  <span class="value">1.0858</span>,
#  <span class="txt_usd"><span class="blind">달러</span></span>,
#  <span class="blind">달러</span>,
#  <span class="change">0.0005</span>,
#  <span class="blind">상승</span>,
#  <span class="time">2024.05.27</span>,
#  <span class="source">모닝스타 기준</span>,
#  <span class="blind">영국 파운드/달러</span>,
#  <span class="value">1.2777</span>,
#  <span class="txt_usd"><span class="blind">달러</span></span>,
#  <span class="blind">달러</span>,
#  <span class="change">0.0036</span>,
#  <span class="blind">상승</span>,
#  <span class="time">2024.05.27</span>,
#  <span class="source">모닝스타 기준</span>,
#  <span class="blind">달러인덱스</span>,
#  <span class="value">104.6300</span>,
#  <span class="change"> 0.4000</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2024.05.24</span>,
#  <span class="source">ICE 기준</span>,
#  <span>유가·금시세</span>,
#  <span class="blind">WTI</span>,
#  <span class="value">77.72</span>,
#  <span class="txt_usd"><span class="blind">달러</span></span>,
#  <span class="blind">달러</span>,
#  <span class="change">0.85</span>,
#  <span class="blind">상승</span>,
#  <span class="time">2024.05.24</span>,
#  <span class="source">NYMEX(뉴욕상업거래소) 기준</span>,
#  <span class="blind">휘발유</span>,
#  <span class="value">1679.78</span>,
#  <span class="txt_krw"><span class="blind">원</span></span>,
#  <span class="blind">원</span>,
#  <span class="change"> 0.70</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2024.05.28</span>,
#  <span class="source">한국석유공사 Opinet 기준</span>,
#  <span class="blind">국제 금</span>,
#  <span class="value">2334.5</span>,
#  <span class="txt_usd"><span class="blind">달러</span></span>,
#  <span class="blind">달러</span>,
#  <span class="change"> 2.70</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2024.05.24</span>,
#  <span class="source">COMEX(뉴욕상품거래소) 기준</span>,
#  <span class="blind">국내 금</span>,
#  <span class="value">103015.47</span>,
#  <span class="txt_krw"><span class="blind">원</span></span>,
#  <span class="blind">원</span>,
#  <span class="change"> 126.87</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2024.05.28 10:13</span>,
#  <span class="source">신한은행 기준</span>,
#  <span class="num">44</span>,
#  <span>환율 주요뉴스</span>,
#  <span>05.28 09:14</span>,
#  <span>05.27 16:45</span>,
#  <span>05.27 16:24</span>,
#  <span>05.27 15:36</span>,
#  <span>05.27 09:20</span>,
#  <span>05.24 16:07</span>,
#  <span>05.24 14:29</span>,
#  <span>05.24 12:00</span>,
#  <span>05.24 09:24</span>,
#  <span>05.24 09:17</span>,
#  <span class="tab1">환전고시 환율</span>,
#  <span class="tab2">국제시장 환율</span>,
#  <span class="tab3">유가 금시세</span>,
#  <span class="tab4">원자재</span>,
#  <span>환율계산기 (매매기준율 기준)</span>,
#  <span class="date">2024.05.28 10:16</span>,
#  <span class="standard">하나은행 기준</span>,
#  <span class="round">고시회차 <em>103</em>회</span>,
#  <span>국내시장금리</span>,
#  <span>CD금리(91일)</span>,
#  <span>콜 금리</span>,
#  <span>국고채 (3년)</span>,
#  <span>회사채 (3년)</span>,
#  <span>COFIX 잔액</span>,
#  <span>COFIX 신규취급액</span>,
#  <span>달러 인덱스</span>,
#  <span>최근조회</span>,
#  <span>MY STOCK</span>,
#  <span>
#  <a href="#" onclick="clickcr(this, 'rch.5', '', '', event); return false;"><img alt="이전" height="15" src="https://ssl.pstatic.net/static/nfinance/btn_prev2.gif" width="17"/></a>
#  <a href="#" onclick="clickcr(this, 'rch.6', '', '', event); return false;"><img alt="다음" height="15" src="https://ssl.pstatic.net/static/nfinance/btn_next2.gif" width="17"/></a>
#  </span>,
#  <span>경제분석 리포트 </span>]

# %%
soup.select("div b")
# Out:
# []

# %%
soup.select("div > b")
# Out:
# []

# %%
soup.select("div.contents")
# Out:
# []

# %%
response = requests.get("https://naver.com")

# %%
response.content
# Out:
# b'   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_240502.css"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>\nwindow["EAGER-DATA"] = window["EAGER-DATA"] || {};\nwindow["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","excludeInPaging":false,"positionForPaging":0,"realtime":false,"filterList":[{"id":"ALL","name":"\xec\x9d\xb8\xea\xb8\xb0","defaultType":true},{"id":"ANIMAL","name":"\xeb\x8f\x99\xeb\xac\xbc","defaultType":false},{"id":"TRAVEL","name":"\xec\x97\xac\xed\x96\x89","defaultType":false},{"id":"WEDDING","name":"\xec\x97\xb0\xec\x95\xa0\xea\xb2\xb0\xed\x98\xbc","defaultType":false},{"id":"MOVIE","name":"\xec\x98\x81\xed\x99\x94","defaultType":false},{"id":"MOMKIDS","name":"\xec\x9c\xa1\xec\x95\x84","defaultType":false}],"needCologger":false,"ad":false,"@type":"PC-FEED-BLOCK","@code":"PC-FEED-RECOMMEND-FILTER-TAB","@template":"PC-FEED-RECOMMEND-FILTER-TAB"},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"\xec\x96\xb4\xeb\xa6\xb0\xec\x9d\xb4\xec\x9a\xa9 \xea\xb2\x8c\xec\x9e\x84\xec\ ...

# %%
url = "https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber=1&pageSize=24"
best_seller = requests.get(url)
print(best_seller)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(best_seller.content,"html.parser")

# %%
best_list = soup.select("#yesBestList div.item_info")
print(len(best_list))
# Out:
# 24

# %%
print(best_list[0])
# Out:
# <div class="item_info">
# <div class="info_row info_keynote">
# <span class="gd_keynote" id="spanGdKeynote">
# <span class="iconC reserv"><em class="txt">예약판매</em></span>
# <!-- 클래스24 상품일 경우 -->
# </span>
# <script type="text/javascript">
#         if ($('#spanGdKeynote').children().length == 0) {
#             $('#spanGdKeynote').remove();
#         }
#     </script>
# </div>
# <div class="info_row info_name">
# <span class="gd_res">[도서]</span>
# <a class="gd_name" href="/Product/Goods/126721830" onclick="wiseLogV2('BS', '001_005_001', ''); ">선재 업고 튀어 대본집 세트</a>
# <span class="gd_feature">[ 이시은 작가, 변우석·김혜윤·송건희·이승협 배우 사인, 메시지 수록, 양장 ]</span>
# <a class="bgYUI ico_nWin" href="/Product/Goods/126721830" onclick="wiseLogV2('BS', '001_005_001', ''); " target="_blank">선재 업고 튀어 대본집 세트 새창이동</a>
# </div>
# <div class="info_row info_pubGrp">
# <span class="authPub info_auth" onclick="wiseLogV2('BS', '001_005_002', '');">
# <a href="https://www.yes24.com/Product/Search?domain=ALL&amp;query=이시은&amp;authorNo=460661&amp;author=이시은" target="">이시은</a> 저
#                             </span>
# <span class="authPub info_pub" onclick="wiseLogV2('BS', '001_005_003', '');"><a href="https://www.yes24.com/Product/Search?&amp;domain=ALL&amp;company=%eb%b6%81%eb%a1%9c%ea%b7%b8%ec%bb%b4%ed%8d%bc%eb%8b%88&amp;query=%eb%b6%81%eb%a1%9c%ea%b7%b8%ec%bb%b4%ed%8d%bc%eb%8b%88">북로그컴퍼니</a></span>
# <span class="authPub info_date">2024년 07월</span>
# </div>
# <dl class="info_present">
# <dt><em class="bgYUI ico_present">구매혜택</em></dt>
# <dd>
#                         [예스24 단독] 홀로그램 포토카드 3종
#                     </dd>
# </dl>
# <div class="info_row info_price">
# <span class="txt_sale"><em class="num">10</em>%</span>
# <strong class="txt_num"><em class="yes_b">45,000</em>원</strong>
# <span class="txt_num dash"><em class="yes_m">50,000</em>원</span>
# <span class="yPoint"><em class="bgYUI ico_point">포인트적립</em>1,000원</span>
# </div>
# <div class="info_row info_rating">
# <span class="saleNum">
#                                 판매지수 785,220
#                             </span>
# <span class="rating_rvCount">
# <a href="https://www.yes24.com/Product/Goods/126721830?ReviewYn=Y" onclick="wiseLogV2('BS', '001_005_004', '');"><em class="bit">회원리뷰</em>(<em class="txC_blue">151</em>건)</a>
# </span>
# <span class="rating_grade">
# <span class="bgYUI tRating tRating_10">리뷰 총점</span><em class="yes_b">10.0</em>
# <span class="moreRatingArea">
# <span class="moreRatingBtn">
# <a class="bgYUI" href="javascript:void(0);" onclick="toggleLiCont(this,$('.sGLi'),event);">정보 더 보기/감추기</a>
# </span>
# <span class="moreRatingLi">
# <span class="moreRatingLiRow">
# <ul class="yesAlertLi">
# <li><em class="bl_dot bgYUI"> </em>종이책 리뷰 (7건)</li>
# <li><em class="bl_dot bgYUI"> </em>eBook 리뷰 (0건)</li>
# <li><em class="bl_dot bgYUI"> </em>종이책 한줄평 (144건)</li>
# <li><em class="bl_dot bgYUI"> </em>eBook 한줄평 (0건)</li>
# </ul>
# </span>
# </span>
# </span>
# </span>
# </div>
# <div class="info_row info_deli" name="delvTextArea"></div>
# <div class="info_row info_signature">
#                     이시은 작가, 변우석·김혜윤·송건희·이승협 배우 사인, 메시지 수록
#                 </div>
# <div class="info_row info_tag">
# <span class="tag">
# <a href="https://www.yes24.com/Product/Search?domain=ALL&amp;query=%eb%8c%80%eb%b3%b8%ec%a7%91&amp;hashNm=%eb%8c%80%eb%b3%b8%ec%a7%91" onclick="wiseLogV2('BS', '001_005_005', ''); setTagClickExtraCode('100', '대본집', '126721830','349');">#대본집</a>
# </span>
# <span class="tag">
# <a href="https://www.yes24.com/Product/Search?domain=ALL&amp;query=%eb%93%9c%eb%9d%bc%eb%a7%88%eb%8c%80%eb%b3%b8%ec%a7%91&amp;hashNm=%eb%93%9c%eb%9d%bc%eb%a7%88%eb%8c%80%eb%b3%b8%ec%a7%91" onclick="wiseLogV2('BS', '001_005_005', ''); setTagClickExtraCode('100', '드라마대본집', '126721830','4165');">#드라마대본집</a>
# </span>
# </div>
# <div class="info_row info_event">
# <div class="event">
# <span class="iconC freeD"><em class="txt">이벤트</em></span>
# <span class="iconC"><em class="txt">사은품</em></span>
# <span class="iconC"><em class="txt">기획전</em></span>
# <span class="txt"><a href="https://event.yes24.com/template?eventNo=248317"> 대본집 출간! 예스24 단독 포토카드 증정!</a></span>
# <span class="date">(24.05.23 ~ 24.07.21)</span>
# </div>
# </div>
# </div>

# %%
print(best_list[0].select_one(".gd_name").text)
# Out:
# 선재 업고 튀어 대본집 세트

# %%
for i in range(len(best_list)):
    print(best_list[i].select_one(".gd_name").text)
# Out:
# 선재 업고 튀어 대본집 세트
# 나는 다정한 관찰자가 되기로 했다
# 하루 한 장 나의 어휘력을 위한 필사 노트
# 나를 소모하지 않는 현명한 태도에 관하여
# 불변의 법칙
# 흔한남매 과학 탐험대 10 생태계
# 세이노의 가르침
# 어떻게 살 것인가
# 오늘부터는 오를 집만 보인다
# 원피스 ONE PIECE 108
# 꽃길이 따로 있나, 내 삶이 꽃인 것을
# 마흔에 읽는 쇼펜하우어
# 홀썸의 집밥 예찬
# 빨모쌤의 라이브 영어회화
# 부자의 마지막 가르침
# 신화의 숲
# 국어 잘하는 아이가 이깁니다
# 돈의 심리학 (30만 부 기념 스페셜 에디션)
# 내 몸 혁명
# Go Go 카카오프렌즈 32 아르헨티나
# 변방에서 중심으로
# 내일의 으뜸
# 일류의 조건
# 흔한남매 16

# %%
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(movie_ranking.content,"html.parser")

# %%
url = "http://www.cine21.com/rank/boxoffice/domestic"
movie_ranking = requests.get(url)
print(movie_ranking)

from bs4 import BeautifulSoup
soup = BeautifulSoup(movie_ranking.content,"html.parser")

if movie_ranking.status_code == 200:
    print("영화 정보를 출력합니다.")
    soup = BeautifulSoup(movie_ranking.content)
    boxoffice = soup.select_one("div#boxoffice_list_content")
    movie_list = boxoffice.select("li.boxoffice_li div.mov_name")
    print(f"수집한 영화 수 : {len(movie_list)}")
    for movie in movie_list:
        print(movie.text)
else:
    print("페이지에 연결할 수 없습니다.")
# Out:
# <Response [200]>
# 영화 정보를 출력합니다.
# 수집한 영화 수 : 0

# %%
url = "https://www.moviechart.co.kr/rank/realtime/index/image"
movie_ranking = requests.get(url)
print(movie_ranking)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(movie_ranking.content,"html.parser")

# %%
movie_list = soup.select(".movieBox-list .movie-title a")
print(len(movie_list))
# Out:
# 20

# %%
print("수집한 영화 수 : ",len(movie_list))
for movie in movie_list:
    print(movie.text)
# Out:
# 수집한 영화 수 :  20
# 설계자
# 퓨리오사: 매드맥스 사가
# 극장판 하이큐!! 쓰레기장의 결전
# 범죄도시4
# 드림 시나리오
# 그녀가 죽었다
# 청춘 18X2 너에게로 이어지는 길
# 바커스: 슈퍼스타가 될 거야
# 결속밴드 라이브 -항성-
# 분노의 강
# 소울메이트
# 혹성탈출: 새로운 시대
# 악마와의 토크쇼
# 오늘부터 댄싱퀸
# 창가의 토토
# 시민덕희
# 별처럼 빛나는 너에게 더무비-일섬일섬량성성
# 챌린저스
# 가필드 더 무비
# 정욕

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.21.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kosa\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.25.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\kosa\anaconda3\lib\site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\kosa\anaconda3\lib\site-packages (from selenium) (4.9.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: sortedcontainers in c:\users\kosa\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\kosa\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\kosa\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\kosa\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\kosa\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\kosa\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading selenium-4.21.0-py3-none-any.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB 10.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.9/9.5 MB 11.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.4/9.5 MB 10.9 MB/s eta 0:00:01
#    -------- ------------------------------- 1.9/9.5 MB 11.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.5/9.5 MB 11.5 MB/s eta 0:00:01
#    ------------- -------------------------- 3.1/9.5 MB 11.6 MB/s eta 0:00:01
#    --------------- ------------------------ 3.7/9.5 MB 11.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.5 MB 11.8 MB/s eta 0:00:01
#    -------------------- ------------------- 4.8/9.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.4/9.5 MB 11.8 MB/s eta 0:00:01
#    ------------------------ --------------- 5.9/9.5 MB 11.8 MB/s eta 0:00:01
#    --------------------------- ------------ 6.4/9.5 MB 11.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.0/9.5 MB 11.8 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.0/9.5 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.6/9.5 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  9.5/9.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 11.4 MB/s eta 0:00:00
# Downloading trio-0.25.1-py3-none-any.whl (467 kB)
#    ---------------------------------------- 0.0/467.7 kB ? eta -:--:--
#    ---------------------------------- ---- 409.6/467.7 kB 12.5 MB/s eta 0:00:01
#    ---------------------------------------- 467.7/467.7 kB 9.7 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB ? eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: h11, attrs, wsproto, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-23.2.0 h11-0.14.0 outcome-1.3.0.post0 selenium-4.21.0 trio-0.25.1 trio-websocket-0.11.1 wsproto-1.2.0

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.close()

# %%
driver.get("https://www.python.org")

# %%
el = driver.find_element(by="id", value="id-search-field")

# %%
el.send_keys("hello")

# %%
el.clear()

# %%
el.send_keys("hello")

# %%
el.send_keys(Keys.RETURN)

# %%
from selenium.webdriver.common.keys import Keys

# %%
result_list = driver.find_elements(by="css selector", value="form ul li h3")

# %%
len(result_list)
# Out:
# 20

# %%
for result in result_list:
    print(result.text)

driver.close()
# Out:
# PEP 3105 -- Make print a function
# Virtual Learning
# Release – Python 3.9.0rc1
# PEP 502 -- String Interpolation - Extended Discussion
# PEP 675 -- Arbitrary Literal String Type
# Release – Python 3.8.2rc2
# Release – Python 3.9.0b1
# Release – Python 3.8.0a1
# PEP 3138 -- String representation in Python 3000
# PEP 3112 -- Bytes literals in Python 3000
# Python Success Stories
# Release – Python 3.9.10
# Release – Python 3.8.1
# Release – Python 3.8.4
# Release – Python 3.8.6
# PEP 289 -- Generator Expressions
# PEP 525 -- Asynchronous Generators
# PEP 604 -- Allow writing union types as X | Y
# EDU-SIG: Python in Education
# PEP 555 -- Context-local variables (contextvars)

# %%
# %%writefile "test.html"
# <!doctype	html>
# <body>
# 	<h1>Welcome</h1>
# 	<form id="loginForm">
# 		<input name="username" type="text">
# 		<input name="password" type="password">
# 		<input type="submit" value="Login">
# 		<input type="button" value="Clear">
# 	</form>
# 	<p>Are you sure	you want to do this?</p>
# 	<a href="http://javaspecialist.co.kr">자바전문가그룹</a>
# 	<p class="content">Site content goes here.</p>
# </body>
# <html>
# Out:
# Writing test.html

# %%
import os
html_file = os.getcwd() + "/test.html"

from selenium import webdriver
driver = webdriver.Chrome()
driver.get("file:///" + html_file)

# %%
login_form = driver.find_element(by='id', value='loginForm')
print(login_form)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7e4f9cc537641a21c1779850d7938688", element="f.2F12B08BB79608A50ABE8D3B1BABDE2D.d.3F0E20E1442CB332F2D72DC5863C7F4A.e.1")>

# %%
username = driver.find_element(by='name', value='username')
username.send_keys("Hello")

# %%
password = driver.find_element(by='name', value='password')
password.send_keys("1234567890")

# %%
login_form = driver.find_element(by='xpath', value="/html/body/form[1]")

# %%
username = driver.find_element(by='xpath', value="//form[input/@name='username']")

# %%
link = driver.find_element(by='link text', value='자바전문가그룹')
link.click()

# %%
heading1 = driver.find_element(by='tag name', value='h1')
print(heading1.text)
# Out:
# Welcome

# %%
content = driver.find_element(by='class name', value='content')
print(content.text)
# Out:
# Site content goes here.

# %%
content = driver.find_element(by='css selector', value='p.content')
print(content.text)
# Out:
# Site content goes here.

# %%
driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()
driver.get("https://www.python.org/")
driver.implicitly_wait(5) #초 단위
menu_list = driver.find_elements(By.CSS_SELECTOR, value="nav#mainnav > ul.navigation > li > a")
for menu in menu_list:
    print(menu.text)
driver.close()
# Out:
# About
# Downloads
# Documentation
# Community
# Success Stories
# News
# Events

# %% [raw]
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support import expected_conditions as EC
# from selenium.webdriver.support.ui import WebDriverWait
# driver = webdriver.Chrome()
# driver.get("https://www.weather.go.kr/w/index.do")
# wait = WebDriverWait(driver, 5) #최대 5초 대기
# element = wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, "div#current-weather span.tmp")))print(element.text)
# driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
driver = webdriver.Chrome()
driver.get("https://www.weather.go.kr/w/index.do")
wait = WebDriverWait(driver, 5) #최대 5초 대기
element = wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, "div#current-weather span.tmp")))
print(element.text)
driver.close()
# Out:
# 25.6℃

# %%
from selenium import webdriver
from selenium.webdriver import ChromeOptions

options = ChromeOptions()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(options=options)

import time
url = "https://www.youtube.com/watch?v=ZVRmnXatgc8"

driver.get(url)
time.sleep(3) #3초 대기

last_page_height = driver.execute_script("return document.documentElement.scrollHeight")
driver.execute_script("window.scrollTo(0, 500);") #500픽셀만 스크롤
time.sleep(1)

driver.find_element(By.CSS_SELECTOR, "div#icon-label").click() #정렬 기준
time.sleep(1)
driver.find_element(By.CSS_SELECTOR, "a[tabindex='-1'] div.item").click()

page_count = 0
while True:
    scroll_script = "window.scrollTo(0, document.documentElement.scrollHeight);"
    driver.execute_script(scroll_script)
    time.sleep(3)
    scroll_height = "return document.documentElement.scrollHeight"
    new_page_height = driver.execute_script(scroll_height)

    if new_page_height==last_page_height:
        break
    last_page_height = new_page_height

    if page_count > 10:
        break
    else:
        page_count += 1

html_source = driver.page_source
driver.close()

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_source, "html.parser")

comments = soup.select("yt-attributed-string#content-text")
users = soup.select("a#author-text > span")

comment_list = [comment.text.strip() for comment in comments]
user_list = [user.text.strip() for user in users]

# %%
import pandas as pd
import numpy as np
comment_df = pd.DataFrame(np.c_[user_list, comment_list], columns=["user", "comment"])
comment_df.to_csv("comment.csv", encoding="utf-8-sig", index=False)

# %%
#셀레니움의 암시적 대기를 이용하는 예
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()
driver.implicitly_wait(3) #3초동안 대기
url = "http://www.cine21.com/rank/boxoffice/domestic"
driver.get(url)
css_selector = "div#boxoffice_list_content li.boxoffice_li div.mov_name"
movie_list = driver.find_elements("css selector", css_selector)
print(f"수집한 영화 수 : {len(movie_list)}")
for movie in movie_list:
    print(movie.text)

driver.close()
# Out:
# 수집한 영화 수 : 20
# 퓨리오사: 매드맥스 사가
# 범죄도시4
# 그녀가 죽었다
# 극장판 하이큐!! 쓰레기장의 결전
# 혹성탈출: 새로운 시대
# 청춘 18X2 너에게로 이어지는 길
# 가필드 더 무비
# 이프: 상상의 친구
# 악마와의 토크쇼
# 남은 인생 10년
# 별처럼 빛나는 너에게 더무비-일섬일섬량성성
# 쇼생크 탈출
# 챌린저스
# 목화솜 피는 날
# 쿵푸팬더4
# 파묘
# 시민덕희
# 땅에 쓰는 시
# 내 손끝에 너의 온도가 닿을 때
# 낸 골딘, 모든 아름다움과 유혈사태
